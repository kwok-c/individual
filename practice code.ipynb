# %%
library(tidyverse)
library(repr)
library(tidymodels)

player <- read_csv("https://raw.githubusercontent.com/kwok-c/individual/refs/heads/main/players.csv")
session <- read_csv("https://raw.githubusercontent.com/kwok-c/individual/refs/heads/main/sessions.csv")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Search for functions across packages at https://www.tidymodels.org/find/
# Error in open.connection(structure(4L, class = c("curl", "connection"), conn_id = <pointer: 0x37e>), : HTTP error 404.
# Traceback:
#
# 1. read_csv("https://raw.githubusercontent.com/kwok-c/individual/refs/heads/main/players.csv")
# 2. vroom::vroom(file, delim = ",", col_names = col_names, col_types = col_types,
#  .     col_select = {
#  .         {
#  .             col_select
#  .         }
#  .     }, id = id, .name_repair = name_repair, skip = skip, n_max = n_max,
#  .     na = na, quote = quote, comment = comment, skip_empty_rows = skip_empty_rows,
#  .     trim_ws = trim_ws, escape_double = TRUE, escape_backslash = FALSE,
#  .     locale = locale, guess_max = guess_max, show_col_types = show_col_types,
#  .     progress = progress, altrep = lazy, num_threads = num_threads)
# 3. vroom_(file, delim = delim %||% col_types$delim, col_names = col_names,
#  .     col_types = col_types, id = id, skip = skip, col_select = col_select,
#  .     name_repair = .name_repair, na = na, quote = quote, trim_ws = trim_ws,
#  .     escape_double = escape_double, escape_backslash = escape_backslash,
#  .     comment = comment, skip_empty_rows = skip_empty_rows, locale = locale,
#  .     guess_max = guess_max, n_max = n_max, altrep = vroom_altrep(altrep),
#  .     num_threads = num_threads, progress = progress)
# 4. (function (con, ...)
#  . UseMethod("open"))(structure(4L, class = c("curl", "connection"
#  . ), conn_id = <pointer: 0x37e>), "rb")
# 5. open.connection(structure(4L, class = c("curl", "connection"), conn_id = <pointer: 0x37e>),
#  .     "rb")

# %% [markdown]
# Title
#
# introduction
#
# Can total time played predict whether or not they are subscribed to a newsletter?
#
# method and results
#
# discussion
#
# references

# %%
data <- player|>
select(played_hours, subscribe)|>
mutate(subscribe=as_factor(subscribe))

data_plot <- ggplot(data, aes(x=played_hours, fill=as_factor(subscribe)))+
geom_histogram()+
facet_grid(rows=vars(subscribe))
data_plot
# Out:
# Error in eval(expr, envir, enclos): object 'player' not found
# Traceback:
#
# 1. mutate(select(player, played_hours, subscribe), subscribe = as_factor(subscribe))
# 2. select(player, played_hours, subscribe)

# %%
count<-data|>
filter(subscribe=="TRUE")
count
# Out:
# Error in UseMethod("filter"): no applicable method for 'filter' applied to an object of class "function"
# Traceback:
#
# 1. filter(data, subscribe == "TRUE")

# %%
set.seed(1)
player_split <- initial_split(data, prop = 0.75, strata = subscribe)
player_train <- training(player_split)
player_test <- testing(player_split)


knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 5) |>
  set_engine("kknn") |>
  set_mode("classification")

knn_recipe <- recipe(subscribe ~ played_hours, data = player_train)

knn_fit <- workflow() |>
  add_recipe(knn_recipe) |>
  add_model(knn_spec) |>
  fit(data = player_train)

fruit_test_predictions <- predict(knn_fit , player_test) |>
bind_cols(player_test)

fruit_prediction_accuracy <- fruit_test_predictions |>
metrics(truth = subscribe, estimate = .pred_class) 
fruit_prediction_accuracy
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.36734694
# 2 kap      binary     0.02440591

# %%
# Out:
#     played_hours subscribe
# 1   30.3         TRUE
# 2    3.8         TRUE
# 3    0.0         FALSE
# 4    0.7         TRUE
# 5    0.1         TRUE
# 6    0.0         TRUE
# 7    0.0         TRUE
# 8    0.0         FALSE
# 9    0.1         TRUE
# 10   0.0         TRUE
# 11   1.6         TRUE
# 12   0.0         TRUE
# 13   1.5         TRUE
# 14   0.2         TRUE
# 15   0.0         TRUE
# 16   0.0         FALSE
# 17   0.0         TRUE
# 18  48.4         TRUE
# 19   0.5         TRUE
# 20   0.6         TRUE
# 21   0.3         TRUE
# 22   0.1         FALSE
# 23   1.0         TRUE
# 24   0.0         TRUE
# 25   0.7         TRUE
# 26   0.6         TRUE
# 27   0.0         TRUE
# 28   0.0         FALSE
# 29   1.8         TRUE
# 30   0.1         FALSE
# ⋮   ⋮            ⋮
# 167  1.0         FALSE
# 168  0.3         FALSE
# 169  0.1         TRUE
# 170  0.1         FALSE
# 171  0.4         FALSE
# 172  1.8         FALSE
# 173  0.0         TRUE
# 174  0.0         FALSE
# 175  0.0         TRUE
# 176  0.3         TRUE
# 177  0.0         FALSE
# 178  2.7         FALSE
# 179  0.4         TRUE
# 180  0.1         TRUE
# 181  2.1         FALSE
# 182  0.8         TRUE
# 183  0.2         FALSE
# 184 32.0         TRUE
# 185  1.7         FALSE
# 186  0.1         FALSE
# 187  0.1         TRUE
# 188  0.0         TRUE
# 189  0.0         TRUE
# 190  0.0         FALSE
# 191  0.0         TRUE
# 192  0.0         TRUE
# 193  0.3         FALSE
# 194  0.0         FALSE
# 195  2.3         FALSE
# 196  0.2         TRUE
